# %% [markdown]
# #Tune plots
# In order to print the plots, input the alg name and parameters. Then the plots for that family will be shown.

# %%
from helper import get_formatted_name
params = {
    'env_name':'FetchPush-v1',
    'alg':'naf',
    'exp_name':'AL47',
    'obs_noise_std':0.0,
    'action_noise_std':0.0,
    'goal_radius':0.05
}
run_path = '/home/gridsan/alagrassa/git/baselines/run_results/'
name = get_formatted_name(params)
print(name)
import sys
sys.path.append("/home/gridsan/alagrassa/git/rl_plot/rl_plot")
import make_plots as mp
import numpy as np
import matplotlib.pyplot as plt
reload(mp)

colors = ['r', (1, 166/255., 0, 1), 'y', 'g', 'b', (149/255.,0,1,1)]
def plot_goal_radiuses(params, goal_radiuses=None, cutoff=None, eps_per_iter=1, data_cutoff=None):
    if goal_radiuses is None:
        goal_radiuses = [0.05, 0.08, 0.01, 0.02, 0.03, 0.1]
    else:
        print(goal_radiuses)
        
    goal_radiuses.sort()
    actual_name = params["exp_name"]
    for goal_radius, color in zip(goal_radiuses, colors):
        params["goal_radius"] = goal_radius
        name = get_formatted_name(params)
        mp.plot_family(run_path+name+"test_success_rates", eps_per_iter=eps_per_iter, data_cutoff=data_cutoff, smoothing=40, display=False, 
                       label="goal radius:"+str(goal_radius), color=color, cutoff=cutoff)
    plt.legend()
    plt.show()
    
def plot_actuation_noise(params, eps_per_iter=1, cutoff=None, goal_radiuses=None, data_cutoff=None):
    if goal_radiuses is None:
        goal_radiuses = [0.0, 0.01, 0.1, 0.2, 0.05, 0.5]
    goal_radiuses.sort()
    actual_name = params["exp_name"]
    for goal_radius, color in zip(goal_radiuses, colors):
        params["action_noise_std"] = goal_radius
        name = get_formatted_name(params)
        mp.plot_family(run_path+name+"test_success_rates", cutoff=cutoff,smoothing=40, data_cutoff=data_cutoff, eps_per_iter=eps_per_iter, display=False, 
                       label="action noise radius:"+str(goal_radius), color=color)
    plt.legend()
    plt.show()

def plot_observation_noise(params, eps_per_iter=1, cutoff=None, goal_radiuses=None, data_cutoff=None):
    if goal_radiuses is None:
        print("goal radiuses was none")
        goal_radiuses = [0.0, 0.01, 0.05, 0.1, 0.2, 0.5]
    goal_radiuses.sort()
    actual_name = params["exp_name"]
    for goal_radius, color in zip(goal_radiuses, colors):
        params["obs_noise_std"] = goal_radius
        name = get_formatted_name(params)
        mp.plot_family(run_path+name+"test_success_rates", cutoff=cutoff,smoothing=40, data_cutoff=data_cutoff,  display=False, 
                       label="obs noise:"+str(goal_radius), color=color)
    plt.legend()
    plt.show()
# Out:
# nafFetchPush-v1AL47obs_0.0act_0.0rw_0.05

# %% [markdown]
# # CMA

# %% [markdown]
#     # CMA goal radius

# %%
params = {
    'env_name':'FetchReach-v1',
    'alg':'cma',
    'exp_name':'AL57',
    'obs_noise_std':0.0,
    'action_noise_std':0.0,
    'goal_radius':0.05
}
cutoff=20000//17
plot_goal_radiuses(params, eps_per_iter =17, cutoff=cutoff)
params['goal_radius']=0.05
plot_actuation_noise(params, eps_per_iter=17, cutoff=cutoff)
params['action_noise_std']=0.0
plot_observation_noise(params,  eps_per_iter=17, cutoff=cutoff)
params['obs_noise_std']=0.0
params["env_name"] = "StirEnv-v0"
params["exp_name"]="AL58"
plot_goal_radiuses(params, eps_per_iter =17, cutoff=cutoff)
params['goal_radius']=0.05
plot_actuation_noise(params, eps_per_iter=17, cutoff=cutoff)
params['action_noise_std']=0.0
plot_observation_noise(params,  eps_per_iter=17, cutoff=cutoff)
params['obs_noise_std']=0.0
arams['env_name'] = 'StirEnv-v0'
data_cutoff=5
params['exp_name'] = "AL58"
goal_radiuses=[68., 72., 74.]
plot_goal_radiuses(params, cutoff=cutoff, data_cutoff=data_cutoff, goal_radiuses=goal_radiuses, eps_per_iter=17)
params['goal_radius']=72.
#plt.show()
plot_actuation_noise(params, cutoff=cutoff, eps_per_iter=17, data_cutoff=data_cutoff)
#plt.show()
params['action_noise_std']=0.0
plot_observation_noise(params, cutoff=cutoff, eps_per_iter=17, data_cutoff=data_cutoff)
params['obs_noise_std']=0.0
# Out:
# ('no files with the root name ', 'cmaFetchReach-v1AL57obs_0.0act_0.0rw_0.02test_success_rates')
# ('No experiments with name', 'cmaFetchReach-v1AL57obs_0.0act_0.0rw_0.02test_success_rates', 'found')
# ('no files with the root name ', 'cmaFetchReach-v1AL57obs_0.0act_0.05rw_0.05test_success_rates')
# ('No experiments with name', 'cmaFetchReach-v1AL57obs_0.0act_0.05rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaFetchReach-v1AL57obs_0.0act_0.5rw_0.05test_success_rates')
# ('No experiments with name', 'cmaFetchReach-v1AL57obs_0.0act_0.5rw_0.05test_success_rates', 'found')
# goal radiuses was none
# ('no files with the root name ', 'cmaFetchReach-v1AL57obs_0.05act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaFetchReach-v1AL57obs_0.05act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaFetchReach-v1AL57obs_0.5act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaFetchReach-v1AL57obs_0.5act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.01test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.01test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.02test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.02test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.03test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.03test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.08test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.08test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.1test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.1test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.01rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.01rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.05rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.05rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.1rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.1rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.2rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.2rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.5rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.5rw_0.05test_success_rates', 'found')
# goal radiuses was none
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.0act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.01act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.01act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.05act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.05act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.1act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.1act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.2act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.2act_0.0rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'cmaStirEnv-v0AL58obs_0.5act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'cmaStirEnv-v0AL58obs_0.5act_0.0rw_0.05test_success_rates', 'found')
# NameErrorTraceback (most recent call last)
# <ipython-input-151-3ba13409bc8b> in <module>()
#      22 plot_observation_noise(params,  eps_per_iter=17, cutoff=cutoff)
#      23 params['obs_noise_std']=0.0
# ---> 24 arams['env_name'] = 'StirEnv-v0'
#      25 data_cutoff=5
#      26 params['exp_name'] = "AL58"
#
# NameError: name 'arams' is not defined

# %% [markdown]
# # PPO goal radius

# %%
params = {
    'env_name':'FetchReach-v1',
    'alg':'ppo2',
    'exp_name':'AL57',
    'obs_noise_std':0.0,
    'action_noise_std':0.0,
    'goal_radius':0.05
}
goal_radiuses=[0.08, 0.05, 0.1]
plt.show()
cutoff=80000//40 #12000//40
data_cutoff=1000
plot_goal_radiuses(params, cutoff=cutoff, data_cutoff=data_cutoff, eps_per_iter=40)
params['goal_radius']=0.05
#plt.show()
plot_actuation_noise(params, cutoff=cutoff, eps_per_iter=40, data_cutoff=data_cutoff)
#plt.show()
params['action_noise_std']=0.0
plot_observation_noise(params, cutoff=cutoff, eps_per_iter=40, data_cutoff=data_cutoff)
params['obs_noise_std']=0.0
params['env_name'] = 'StirEnv-v0'
data_cutoff=5
params['exp_name'] = "AL58"
goal_radiuses=[68., 72., 74.]
plot_goal_radiuses(params, cutoff=cutoff, data_cutoff=data_cutoff, goal_radiuses=goal_radiuses, eps_per_iter=5)
params['goal_radius']=72.
#plt.show()
plot_actuation_noise(params, cutoff=cutoff, eps_per_iter=5, data_cutoff=data_cutoff)
#plt.show()
params['action_noise_std']=0.0
plot_observation_noise(params, cutoff=cutoff, eps_per_iter=5, data_cutoff=data_cutoff)
params['obs_noise_std']=0.0
# Out:
# ('no files with the root name ', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.01test_success_rates')
# ('No experiments with name', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.01test_success_rates', 'found')
# ('no files with the root name ', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.02test_success_rates')
# ('No experiments with name', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.02test_success_rates', 'found')
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.05test_success_rates_5.npy', 'because the data was too short at ', 332)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.08test_success_rates_8.npy', 'because the data was too short at ', 152)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.08test_success_rates_3.npy', 'because the data was too short at ', 142)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.05test_success_rates_5.npy', 'because the data was too short at ', 332)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.01rw_0.05test_success_rates_8.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.01rw_0.05test_success_rates_7.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.01rw_0.05test_success_rates_2.npy', 'because the data was too short at ', 332)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.01rw_0.05test_success_rates_4.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.01rw_0.05test_success_rates_6.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.01rw_0.05test_success_rates_3.npy', 'because the data was too short at ', 332)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.01rw_0.05test_success_rates_1.npy', 'because the data was too short at ', 342)
# ('no files with the root name ', 'ppo2FetchReach-v1AL57obs_0.0act_0.05rw_0.05test_success_rates')
# ('No experiments with name', 'ppo2FetchReach-v1AL57obs_0.0act_0.05rw_0.05test_success_rates', 'found')
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.1rw_0.05test_success_rates_3.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.1rw_0.05test_success_rates_8.npy', 'because the data was too short at ', 332)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.1rw_0.05test_success_rates_4.npy', 'because the data was too short at ', 332)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.1rw_0.05test_success_rates_7.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.1rw_0.05test_success_rates_6.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.1rw_0.05test_success_rates_2.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.1rw_0.05test_success_rates_1.npy', 'because the data was too short at ', 342)
# ('no files with the root name ', 'ppo2FetchReach-v1AL57obs_0.0act_0.5rw_0.05test_success_rates')
# ('No experiments with name', 'ppo2FetchReach-v1AL57obs_0.0act_0.5rw_0.05test_success_rates', 'found')
# goal radiuses was none
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.0act_0.0rw_0.05test_success_rates_5.npy', 'because the data was too short at ', 332)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.01act_0.0rw_0.05test_success_rates_8.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.01act_0.0rw_0.05test_success_rates_4.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.01act_0.0rw_0.05test_success_rates_5.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.01act_0.0rw_0.05test_success_rates_1.npy', 'because the data was too short at ', 342)
# ('Excluded ', 'ppo2FetchReach-v1AL57obs_0.01act_0.0rw_0.05test_success_rates_2.npy', 'because the data was too short at ', 342)
# ('no files with the root name ', 'ppo2FetchReach-v1AL57obs_0.5act_0.0rw_0.05test_success_rates')
# ('No experiments with name', 'ppo2FetchReach-v1AL57obs_0.5act_0.0rw_0.05test_success_rates', 'found')
# [68.0, 72.0, 74.0]
# ('no files with the root name ', 'ppo2StirEnv-v0AL58obs_0.0act_0.05rw_72.0test_success_rates')
# ('No experiments with name', 'ppo2StirEnv-v0AL58obs_0.0act_0.05rw_72.0test_success_rates', 'found')
# ('no files with the root name ', 'ppo2StirEnv-v0AL58obs_0.0act_0.2rw_72.0test_success_rates')
# ('No experiments with name', 'ppo2StirEnv-v0AL58obs_0.0act_0.2rw_72.0test_success_rates', 'found')
# ('no files with the root name ', 'ppo2StirEnv-v0AL58obs_0.0act_0.5rw_72.0test_success_rates')
# ('No experiments with name', 'ppo2StirEnv-v0AL58obs_0.0act_0.5rw_72.0test_success_rates', 'found')
# goal radiuses was none
# ('no files with the root name ', 'ppo2StirEnv-v0AL58obs_0.05act_0.0rw_72.0test_success_rates')
# ('No experiments with name', 'ppo2StirEnv-v0AL58obs_0.05act_0.0rw_72.0test_success_rates', 'found')
# ('no files with the root name ', 'ppo2StirEnv-v0AL58obs_0.2act_0.0rw_72.0test_success_rates')
# ('No experiments with name', 'ppo2StirEnv-v0AL58obs_0.2act_0.0rw_72.0test_success_rates', 'found')
# ('no files with the root name ', 'ppo2StirEnv-v0AL58obs_0.5act_0.0rw_72.0test_success_rates')
# ('No experiments with name', 'ppo2StirEnv-v0AL58obs_0.5act_0.0rw_72.0test_success_rates', 'found')

# %% [markdown]
# # HER goal radius

# %%
params = {
    'env_name':'FetchPush-v1',
    'alg':'her',
    'exp_name':'AL57',
    'obs_noise_std':0.0,
    'action_noise_std':0.0,
    'goal_radius':0.05
}
eps_per_iter =10 
plot_goal_radiuses(params, cutoff=None, eps_per_iter=eps_per_iter)
# Out:
# ('no files with the root name ', 'herFetchPush-v1AL57obs_0.0act_0.0rw_0.02test_success_rates')
# ('No experiments with name', 'herFetchPush-v1AL57obs_0.0act_0.0rw_0.02test_success_rates', 'found')

# %% [markdown]
# # HER actuation noise

# %%
params = {
    'env_name':'FetchPush-v1',
    'alg':'her',
    'exp_name':'AL57',
    'obs_noise_std':0.0,
    'action_noise_std':0.0,
    'goal_radius':0.05
}
plot_actuation_noise(params, cutoff=1000, eps_per_iter=10)

plt.show()
# Out:
# ('no files with the root name ', 'herFetchPush-v1AL57obs_0.0act_0.05rw_0.05test_success_rates')
# ('No experiments with name', 'herFetchPush-v1AL57obs_0.0act_0.05rw_0.05test_success_rates', 'found')
# ('no files with the root name ', 'herFetchPush-v1AL57obs_0.0act_0.5rw_0.05test_success_rates')
# ('No experiments with name', 'herFetchPush-v1AL57obs_0.0act_0.5rw_0.05test_success_rates', 'found')

# %% [markdown]
# # HER observation noise

# %%
params = {
    'env_name':'FetchPush-v1',
    'alg':'her',
    'exp_name':'AL57',
    'obs_noise_std':0.0,
    'action_noise_std':0.0,
    'goal_radius':0.05
}
plot_observation_noise(params, eps_per_iter=10, cutoff=None)
plt.show()
# Out:
# goal radiuses was none
